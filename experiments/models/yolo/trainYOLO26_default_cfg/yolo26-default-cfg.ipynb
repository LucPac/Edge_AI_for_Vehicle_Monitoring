# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 22.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# %%writefile /kaggle/working/data.yaml
#
# names:
# - car
# - motorcycle
# - plate
# nc: 3
# test: /kaggle/input/datasets/lucpac/vehicle-plate-det/dataset_yolo/test/images
# train: /kaggle/input/datasets/lucpac/vehicle-plate-det/dataset_yolo/train/images
# val: /kaggle/input/datasets/lucpac/vehicle-plate-det/dataset_yolo/valid/images
# Out:
# Writing /kaggle/working/data.yaml

# %%
from ultralytics import YOLO
model = YOLO('yolo26n.pt')

results = model.train(
    data='/kaggle/working/data.yaml',
    epochs=300,
    imgsz=640,
    batch=16,
    device=[0,1],
    patience=50,
    project='runs/train',
    name='exp',
    save=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# ...

# %%
# %cd /kaggle/working
# !zip -r full_kaggle_workspace.zip ./*
# Out:
# /kaggle/working
#   adding: data.yaml (deflated 58%)
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/runs/ (stored 0%)
#   adding: runs/detect/runs/train/ (stored 0%)
#   adding: runs/detect/runs/train/exp/ (stored 0%)
#   adding: runs/detect/runs/train/exp/val_batch2_labels.jpg (deflated 8%)
#   adding: runs/detect/runs/train/exp/val_batch0_pred.jpg (deflated 4%)
#   adding: runs/detect/runs/train/exp/val_batch2_pred.jpg (deflated 8%)
#   adding: runs/detect/runs/train/exp/weights/ (stored 0%)
#   adding: runs/detect/runs/train/exp/weights/last.pt (deflated 12%)
#   adding: runs/detect/runs/train/exp/weights/best.pt (deflated 12%)
#   adding: runs/detect/runs/train/exp/BoxF1_curve.png (deflated 13%)
#   adding: runs/detect/runs/train/exp/train_batch1.jpg (deflated 4%)
#   adding: runs/detect/runs/train/exp/train_batch2.jpg (deflated 4%)
#   adding: runs/detect/runs/train/exp/BoxR_curve.png (deflated 12%)
# ...

# %%
# %cd "D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLO26_default_cfg"
# Out:
# D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLO26_default_cfg
# d:\Dropbox\GitHub\RASPBERRY_Parking_lot\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !yolo export model="exp/weights/best.pt" format=onnx opset=12
# Out:
# Ultralytics 8.4.24  Python-3.10.0 torch-2.0.1+cpu CPU (AMD Ryzen AI 7 350 w/ Radeon 860M)
# YOLO26n summary (fused): 122 layers, 2,375,421 parameters, 0 gradients, 5.2 GFLOPs
#
# PyTorch: starting from 'exp\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 12...
# ============== Diagnostic Run torch.onnx.export version 2.0.1+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: slimming with onnxslim 0.1.90...
# ONNX: export success  1.5s, saved as 'exp\weights\best.onnx' (9.4 MB)
#
# Export complete (1.9s)
# Results saved to D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLO26_default_cfg\exp\weights
# Predict:         yolo predict task=detect model=exp\weights\best.onnx imgsz=640
# ...
