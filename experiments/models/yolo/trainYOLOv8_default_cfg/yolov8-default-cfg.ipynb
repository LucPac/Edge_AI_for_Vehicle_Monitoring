# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.4 MB/s eta 0:00:0000:0100:01
# ...

# %%
# %%writefile /kaggle/working/data.yaml
#
# names:
# - car
# - motorcycle
# - plate
# nc: 3
# test: /kaggle/input/datasets/tada924/vehicle-plate-det/dataset_yolo/test/images
# train: /kaggle/input/datasets/tada924/vehicle-plate-det/dataset_yolo/train/images
# val: /kaggle/input/datasets/tada924/vehicle-plate-det/dataset_yolo/valid/images
# Out:
# Writing /kaggle/working/data.yaml

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')

results = model.train(
    data='/kaggle/working/data.yaml',
    epochs=300,
    imgsz=640,
    batch=16,
    device=[0,1],
    patience=50,
    project='runs/train',
    name='exp',
    save=True
)
# Out:
# ...
# Ultralytics 8.4.41 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# ...

# %%
# %cd /kaggle/working
# !zip -r full_kaggle_workspace.zip ./*
# Out:
# /kaggle/working
#   adding: data.yaml (deflated 58%)
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/runs/ (stored 0%)
#   adding: runs/detect/runs/train/ (stored 0%)
#   adding: runs/detect/runs/train/exp/ (stored 0%)
#   adding: runs/detect/runs/train/exp/results.png (deflated 9%)
#   adding: runs/detect/runs/train/exp/BoxPR_curve.png (deflated 17%)
#   adding: runs/detect/runs/train/exp/labels.jpg (deflated 30%)
#   adding: runs/detect/runs/train/exp/results.csv (deflated 70%)
#   adding: runs/detect/runs/train/exp/val_batch0_pred.jpg (deflated 4%)
#   adding: runs/detect/runs/train/exp/val_batch1_labels.jpg (deflated 6%)
#   adding: runs/detect/runs/train/exp/val_batch0_labels.jpg (deflated 4%)
#   adding: runs/detect/runs/train/exp/val_batch1_pred.jpg (deflated 6%)
#   adding: runs/detect/runs/train/exp/confusion_matrix_normalized.png (deflated 28%)
#   adding: runs/detect/runs/train/exp/train_batch2.jpg (deflated 4%)
# ...

# %%
# %cd "D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLOv8_default_cfg"
# Out:
# D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLOv8_default_cfg
# d:\Dropbox\GitHub\RASPBERRY_Parking_lot\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install ultralytics

# %%
# !yolo export model="exp/weights/best.pt" format=onnx opset=12
# Out:
# Ultralytics 8.4.24  Python-3.10.0 torch-2.0.1+cpu CPU (AMD Ryzen AI 7 350 w/ Radeon 860M)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from 'exp\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 7, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 12...
# ============== Diagnostic Run torch.onnx.export version 2.0.1+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
#
# ONNX: slimming with onnxslim 0.1.90...
# ONNX: export success  1.2s, saved as 'exp\weights\best.onnx' (11.7 MB)
#
# Export complete (1.6s)
# Results saved to D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLOv8_default_cfg\exp\weights
# Predict:         yolo predict task=detect model=exp\weights\best.onnx imgsz=640
# ...
