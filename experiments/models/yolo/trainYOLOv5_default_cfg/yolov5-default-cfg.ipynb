# %%
# %cd /kaggle/working/
# Out:
# /kaggle/working

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17898, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 17898 (delta 39), reused 9 (delta 9), pack-reused 17850 (from 5)
# Receiving objects: 100% (17898/17898), 17.06 MiB | 28.09 MiB/s, done.
# Resolving deltas: 100% (12193/12193), done.

# %%
# %cd /kaggle/working/yolov5
# !pip install -r requirements.txt
# Out:
# /kaggle/working/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 9.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.25.1 requires google-cloud-bigquery-storage>=2.0.0, which is not installed.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.2.0 which is incompatible.
# ...

# %%
# %%writefile /kaggle/working/data.yaml
#
# names:
# - car
# - motorcycle
# - plate
# nc: 3
# test: /kaggle/input/datasets/lucpac/vehicle-plate-det/dataset_yolo/test/images
# train: /kaggle/input/datasets/lucpac/vehicle-plate-det/dataset_yolo/train/images
# val: /kaggle/input/datasets/lucpac/vehicle-plate-det/dataset_yolo/valid/images
# Out:
# Writing /kaggle/working/data.yaml

# %%
# !python train.py --img 640 --batch 16 --epochs 300 --device 0,1 --patience 50 --data /kaggle/working/data.yaml --weights yolov5n.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-04-23 04:46:55.683720: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776919615.906130     120 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python train.py --resume runs/train/exp/weights/last.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-04-23 07:11:49.705064: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776928309.942596   41941 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776928310.013492   41941 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776928310.555899   41941 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python train.py --resume runs/train/exp/weights/last.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2026-04-23 10:02:08.807083: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776938529.041535   83767 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776938529.114466   83767 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776938529.650438   83767 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# %cd /kaggle/working
# !zip -r full_kaggle_workspace.zip ./*
# Out:
# /kaggle/working
#   adding: data.yaml (deflated 58%)
#   adding: yolov5/ (stored 0%)
#   adding: yolov5/.gitignore (deflated 55%)
#   adding: yolov5/CONTRIBUTING.md (deflated 58%)
#   adding: yolov5/runs/ (stored 0%)
#   adding: yolov5/runs/train/ (stored 0%)
#   adding: yolov5/runs/train/exp/ (stored 0%)
#   adding: yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 4%)
#   adding: yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: yolov5/runs/train/exp/val_batch2_labels.jpg (deflated 6%)
#   adding: yolov5/runs/train/exp/val_batch1_pred.jpg (deflated 8%)
#   adding: yolov5/runs/train/exp/val_batch0_labels.jpg (deflated 4%)
#   adding: yolov5/runs/train/exp/train_batch0.jpg (deflated 2%)
#   adding: yolov5/runs/train/exp/train_batch1.jpg (deflated 2%)
#   adding: yolov5/runs/train/exp/P_curve.png (deflated 13%)
#   adding: yolov5/runs/train/exp/train_batch2.jpg (deflated 2%)
#   adding: yolov5/runs/train/exp/events.out.tfevents.1776938573.aad3766bc058.83767.0 (deflated 13%)
# ...

# %%
# %cd "D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLOv5_default_cfg\full_kaggle_workspace\yolov5"
# Out:
# D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLOv5_default_cfg\full_kaggle_workspace\yolov5
# d:\Dropbox\GitHub\RASPBERRY_Parking_lot\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install onnx onnxruntime
# !pip install torch==2.0.1 torchvision==0.15.2 --index-url https://download.pytorch.org/whl/cpu
# Out:
# ...
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
#      ---------------------------------------- 0.0/174.0 MB ? eta -:--:--
#      ---------------------------------------- 1.0/174.0 MB 8.5 MB/s eta 0:00:21
#      - ------------------------------------- 8.7/174.0 MB 26.9 MB/s eta 0:00:07
#      --- ---------------------------------- 14.4/174.0 MB 26.7 MB/s eta 0:00:06
#      --- ---------------------------------- 17.6/174.0 MB 25.8 MB/s eta 0:00:07
#      --- ---------------------------------- 18.1/174.0 MB 19.4 MB/s eta 0:00:09
#      ---- --------------------------------- 19.7/174.0 MB 17.0 MB/s eta 0:00:10
#      ---- --------------------------------- 21.5/174.0 MB 15.4 MB/s eta 0:00:10
#      ---- --------------------------------- 22.8/174.0 MB 14.7 MB/s eta 0:00:11
#      ---- --------------------------------- 22.8/174.0 MB 14.7 MB/s eta 0:00:11
#      ----- -------------------------------- 24.9/174.0 MB 12.3 MB/s eta 0:00:13
# ...

# %%
# !python export.py --weights "runs/train/exp/weights/best.pt" --include onnx --opset 12
# Out:
# ============== Diagnostic Run torch.onnx.export version 2.0.1+cpu ==============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================
# d:\Dropbox\GitHub\RASPBERRY_Parking_lot\venv\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.3)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(
# export: data=D:\Dropbox\GitHub\RASPBERRY_Parking_lot\experiments\models\yolo\trainYOLOv5_default_cfg\full_kaggle_workspace\yolov5\data\coco128.yaml, weights=['runs/train/exp/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=False, mlmodel=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# ...
